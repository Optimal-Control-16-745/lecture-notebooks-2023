# %%
using Pkg; Pkg.activate("."); Pkg.instantiate()
using LinearAlgebra
using PyPlot
using ControlSystems
# Out:
#   Activating project at `~/OCRL/RL`

# %%
#1D Double-Integrator Problem
N = 15
n = 2
m = 1
x0 = [1.0; 0]
dt = 1.0
A = [1 dt; 0 1];
B = [0.5*dt*dt; dt];

# %%
#LQR Cost Matrices
Q = Array(1.0*I(2))
R = Array(0.1*I(1))
#Qf = Array(1.0*I(2));
Qf = dare(A,B,Q,R); #This makes sure that the infinite-horizon K is the solution to the finite-horizon problem

# %%
#Cost Function
function cost(xtraj,utraj,Q,R,Qf)
    J = 0.0
    for k = 1:(N-1)
        J += 0.5*xtraj[:,k]'*Q*xtraj[:,k] + 0.5*(utraj[k]'*R*utraj[k])[1]
    end
    J += 0.5*xtraj[:,N]'*Qf*xtraj[:,N]
end
#Cost Function
function cost_to_go(xtraj,utraj,Q,R,Qf)
    costvec = zeros(N)
    for k = 1:(N-1)
        costvec[k] = 0.5*xtraj[:,k]'*Q*xtraj[:,k] + 0.5*(utraj[k]'*R*utraj[k])[1]
    end
    costvec[N] = 0.5*xtraj[:,N]'*Qf*xtraj[:,N]
    cost_to_go = zeros(N)
    for k = 1:N
        cost_to_go[k] = sum(costvec[k:end])
    end
    return cost_to_go
end
# Out:
# cost_to_go (generic function with 1 method)

# %%
#Groud Truth Solution (Infinite-Horizon LQR Gain)
K_true = dlqr(A,B,Q,R)
# Out:
# 1×2 Matrix{Float64}:
#  0.616695  1.27032

# %%
#Ground-truth Closed-loop simulation with LQR controller

function rollout!(xtraj,utraj,vtraj,x0,K,V,W)
    xtraj[:,1] .= x0
    for k = 1:(N-1)
        vtraj[k] = sqrt(V)*randn()
        utraj[k] = (-K*xtraj[:,k])[1] + vtraj[k]
        xtraj[:,k+1] .= A*xtraj[:,k] + B*utraj[k] + sqrt(W)*randn(2)
    end
end
    
xtraj_true = zeros(n,N)
utraj_true = zeros(N-1)
vtraj_true = zeros(N-1)

rollout!(xtraj_true,utraj_true,vtraj_true,x0,K_true,0,zeros(2,2))

# %%
plot(xtraj_true[1,:])
plot(xtraj_true[2,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f98ec150d30>

# %%
plot(utraj_true)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f98e628b8d0>

# %%
#Policy-Gradient Algorithm
iter = 400 #number of outer-loop iterations
batch_size = 50 #number of rollouts per minibatch to estimate policy gradient

α0 = 0.05 #step size ("learning rate")
β1 = 0.9
β2 = 0.999
ϵ = 1e-8

V = 0.01 #noise covariance for policy ("exploration")
W = zeros(2,2) #noise covariance for dynamics (process noise)

K0 = zeros(1,2)
K = deepcopy(K0)
iter_costs = zeros(iter)
batch_costs = zeros(N,batch_size)
batch_vxt = zeros(N-1, 2, batch_size)

adam_m = zeros(1,2)
adam_v = zeros(1,2)

xtraj_pg = zeros(2,N)
utraj_pg = zeros(N-1)
vtraj_pg = zeros(N-1);

# %%
#Vanilla SGD
for k = 1:iter
    
    #Do a bunch of rollouts with stochastic policy
    for j = 1:batch_size
        rollout!(xtraj_pg,utraj_pg,vtraj_pg,x0,K,V,W)
        batch_costs[:,j] = cost_to_go(xtraj_pg,utraj_pg,Q,R,Qf)
        batch_vxt[:,:,j] .= reshape(vtraj_pg, N-1, 1).*xtraj_pg[:,1:N-1]'
    end
    #Evaluate policy gradient from batch
    grad = zeros(1,2)
    for j = 1:batch_size
        grad -= sum(reshape(((batch_costs[1:N-1,j])./batch_size), N-1, 1).*batch_vxt[:,:,j], dims=1)
    end
        
    #Take Adam step on K using gradient estimate!
    adam_m = β1*adam_m + (1-β1)*grad
    adam_v = β2*adam_v + (1-β2)*(grad.*grad)
    α = α0*sqrt(1-β2^(k+1))/(1-β1^(k+1))
    K -= α*adam_m./(sqrt.(adam_v).+ϵ)
    
    #Evaluate cost for plotting
    rollout!(xtraj_pg,utraj_pg,vtraj_pg,x0,K,0,zeros(2,2))
    iter_costs[k] = cost(xtraj_pg,utraj_pg,Q,R,Qf)
end

# %%
plot(iter_costs)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f98e42f2358>

# %%
true_cost = cost(xtraj_true,utraj_true,Q,R,Qf)
# Out:
# 1.0299384521582335

# %%
iter_costs[end]
# Out:
# 1.0357714929675148

# %%
K_true
# Out:
# 1×2 Matrix{Float64}:
#  0.616695  1.27032

# %%
K
# Out:
# 1×2 Matrix{Float64}:
#  0.672662  1.27401

# %%
plot(xtraj_pg[1,:])
plot(xtraj_pg[2,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f30da515b00>
